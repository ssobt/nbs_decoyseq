# %%
## Notebook env: seuratdisk (R kernel)
## this notebook spits out the input mtx

# %%
library(SeuratDisk)
library(Seurat)
library(Matrix)
library(ggplot2)
# Out:
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat
#
# Attaching SeuratObject
#
# Attaching sp

# %%
miR_seurat = LoadH5Seurat('/home/ssobti/projects/mir_tud/010523_filtered_data/miR.integrated.qc_norm_scaled.dimred.clustered.gex.guide_assigned.h5seurat')
# Out:
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding miscellaneous information for RNA
#
# Initializing integrated with data
#
# Adding scale.data for integrated
#
# Adding variable feature information for integrated
#
# Adding reduction pca
#
# Adding cell embeddings for pca
#
# Adding feature loadings for pca
#
# Adding miscellaneous information for pca
#
# Adding reduction umap
#
# Adding cell embeddings for umap
#
# Adding miscellaneous information for umap
#
# Adding graph integrated_nn
#
# Adding graph integrated_snn
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
#
# Adding data that was not associated with an assay
#
# Warning message:
# “Adding a command log without an assay associated with it”

# %%
DimPlot(miR_seurat)
# Out:
# plot without title

# %%
normalized_data = miR_seurat@assays$RNA@data
gene_names = rownames(normalized_data)

# %%
hist(normalized_data[2,])
# Out:
# Plot with title “Histogram of normalized_data[2, ]”

# %%
meta = miR_seurat@meta.data

# %%
head(meta)
# Out:
#                          nCount_RNA nFeature_RNA orig.ident sample
# miR_1:AAACCCAAGGAGAGGC-1 33954      5998         miR        miR_1
# miR_1:AAACCCAAGGTAAACT-1 31928      6868         miR        miR_1
# miR_1:AAACCCACAACGATCT-1 42785      7447         miR        miR_1
# miR_1:AAACCCACACGATTCA-1 58537      8039         miR        miR_1
# miR_1:AAACCCACAGTCAACT-1 31579      6580         miR        miR_1
# miR_1:AAACCCACATCTCATT-1 20694      5353         miR        miR_1
#                          barcode          guide           lor
# miR_1:AAACCCAAGGAGAGGC-1 AAACCCAAGGAGAGGC hsa-miR-203a-3p 5.453121
# miR_1:AAACCCAAGGTAAACT-1 AAACCCAAGGTAAACT hsa-miR-93-3p   6.012001
# miR_1:AAACCCACAACGATCT-1 AAACCCACAACGATCT hsa-miR-130b-3p 5.864701
# miR_1:AAACCCACACGATTCA-1 AAACCCACACGATTCA TuD_NC_18       5.859895
# miR_1:AAACCCACAGTCAACT-1 AAACCCACAGTCAACT hsa-miR-147b-5p 5.632808
# miR_1:AAACCCACATCTCATT-1 AAACCCACATCTCATT hsa-miR-501-5p  5.261722
# ...

# %%
guide_vector = meta$miR.family

# %%
guide_vector[guide_vector == 'NA'] = 'TuD_NC'

# %%
guide_vector[1:5]
# Out:
# [1] "miR-203a-3p.1"            "miR-93-3p"
# [3] "miR-130-3p/301-3p/454-3p" "TuD_NC"
# [5] "miR-147b"

# %%
meta$guide = guide_vector

# %%
Matrix::writeMM(normalized_data, '/home/ssobti/projects/mir_tud/010523_filtered_data/miR_normalized_data.mtx')
# Out:
# NULL

# %%
write.csv(gene_names, '/home/ssobti/projects/mir_tud/010523_filtered_data/miR_gene_names.csv')
write.csv(meta, '/home/ssobti/projects/mir_tud/010523_filtered_data/miR_meta.csv')

# %%
miR_seurat <- FindVariableFeatures(miR_seurat, selection.method = "vst", nfeatures = 2000)
# Out:
# Warning message in FindVariableFeatures.Assay(object = assay.data, selection.method = selection.method, :
# “selection.method set to 'vst' but count slot is empty; will use data slot instead”
# Warning message in eval(predvars, data, env):
# “NaNs produced”
# Warning message in hvf.info$variance.expected[not.const] <- 10^fit$fitted:
# “number of items to replace is not a multiple of replacement length”

# %%
VariableFeaturePlot(miR_seurat) -> plot1
top10 <- head(VariableFeatures(miR_seurat), 10)
plot2 <- LabelPoints(plot = plot1, points = top10, repel = TRUE)
plot2
# Out:
# When using repel, set xnudge and ynudge to 0 for optimal results
#
# Warning message in self$trans$transform(x):
# “NaNs produced”
# Warning message:
# “Transformation introduced infinite values in continuous x-axis”
# Warning message:
# “Removed 2 rows containing missing values (geom_point).”
# plot without title

# %%
top_variable_genes = VariableFeatures(miR_seurat)

# %%
write.csv(top_variable_genes, file = '/home/ssobti/projects/mir_tud/output_data/heterogeneity/updated_input_data/top_var_genes.csv')

# %%
class(normalized_data)
# Out:
# [1] "dgCMatrix"
# attr(,"package")
# [1] "Matrix"

# %%
normalized_data = as(normalized_data, 'dgCMatrix')

# %%
medians = sparseMatrixStats::rowMedians(normalized_data)

# %%
median_df = data.frame(gene_medians = medians)

# %%
ggplot(median_df, aes(x=gene_medians)) + 
  geom_histogram(color="black", fill="white", bins = 50000) +
  theme_bw()
# Out:
# plot without title

# %%
ggplot(median_df, aes(x=gene_medians)) + 
  geom_histogram(color="black", fill="white", bins = 50000) +
  coord_cartesian(xlim = c(0,200)) +
  theme_bw()
# Out:
# plot without title

# %%
ggplot(median_df, aes(x=gene_medians)) + 
  geom_histogram(color="black", fill="white", bins = 50000) +
  coord_cartesian(xlim = c(0,1)) +
  theme_bw()
# Out:
# plot without title

# %%
ggplot(median_df, aes(x=gene_medians)) + 
  geom_histogram(color="black", fill="white", bins = 50000) +
  coord_cartesian(xlim = c(0.0001,1)) +
  theme_bw()
# Out:
# plot without title
