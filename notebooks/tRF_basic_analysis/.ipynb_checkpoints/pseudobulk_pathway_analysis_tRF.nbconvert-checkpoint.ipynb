# %%
## Notebook env: mirtud_env (R kernel)
## this notebook finds expression patterns in aggregated datasets

# %%
suppressMessages(library(Seurat))
suppressMessages(library(stringr))
suppressMessages(library(ggplot2))
suppressMessages(library(escape))
suppressMessages(library(dittoSeq))
suppressMessages(library(GSEABase))
suppressMessages(library(SummarizedExperiment))

# %%
tRF_loaded_seuratobj <- readRDS('/home/ssobti/projects/mir_tud/010523_filtered_data/tRF_normalized_integrated_seurat.rds')
meta = tRF_loaded_seuratobj@meta.data

meta$guide[str_sub(meta$guide, 1, 3) == 'TuD'] <- 'TuD_NC'
tRF_loaded_seuratobj@meta.data <- meta

# %%
count_df = data.frame(guide = names(table(meta$guide)), cells = as.numeric(table(meta$guide)))
ggplot(count_df, aes(x = cells)) + geom_histogram(color="black", fill="white", position = "identity", bins = 1000) + 
xlim(0,150) + theme_classic()
# Out:
# Warning message:
# “Removed 36 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_bar()`).”
# plot without title

# %%
suppressMessages(library(dplyr))
cbind(arrange(count_df, cells)[1:10,], arrange(count_df, -cells)[1:10,])
# Out:
#    guide                  cells guide                 cells
# 1  tRF_Leu_CAA.CAG_2      1     TuD_NC                7753
# 2  tRNA-Arg-TCG-2-1.3t    1     tRF_Ala_TGC.AGC_6      598
# 3  tRNA-Cys-GCA-4-1.3t    1     tRF_Asn_GTT_2          501
# 4  tRNA-Gln-CTG-(5)1-1.1t 1     tRF_Ala_CGC.AGC.TGC_5  477
# 5  tRNA-Lys-TTT-(5)3-1.1t 1     tRF_Gly_CCC_2          469
# 6  tRNA-Met-CAT-(2)3-1.1t 1     tRF_Lys_CTT_2          425
# 7  tRNA-Val-AAC-3-1.3t    1     tRF_Leu_TAA_2          390
# 8  tRNA-Val-CAC-2-1.3t    1     tRF_Gly_TCC_4          377
# 9  tRNA-Val-CAC-3-1.3t    1     tRF_Ser_CGA_2          333
# 10 tRNA-Val-CAC-6-1.3t    1     tRF_Val_CAC.AAC_6      325

# %%
### seems like # of cells per guide is a huge covariate in expression (based on heatmap below without regressing it out)
## so need to control for it here
cell_guide_count = 1:nrow(meta)
for (i in 1:nrow(count_df)){
    cell_guide_count[meta$guide == count_df$guide[i]] = count_df$cells[i]
}

meta$cell_guide_count = cell_guide_count
tRF_loaded_seuratobj@meta.data <- meta

# %%
tRF_seuratobj = CreateSeuratObject(tRF_loaded_seuratobj@assays$RNA@counts, meta.data = tRF_loaded_seuratobj@meta.data)
tRF_seuratobj = NormalizeData(tRF_seuratobj)

# %%
tRF_seuratobj_rel_norlmalized = CreateSeuratObject(tRF_loaded_seuratobj@assays$RNA@counts, meta.data = tRF_loaded_seuratobj@meta.data)
tRF_seuratobj_rel_norlmalized = NormalizeData(tRF_seuratobj_rel_norlmalized, normalization.method = 'RC')

# %%
#tRF_seuratobj = ScaleData(tRF_seuratobj, features = rownames(tRF_seuratobj), vars.to.regress = c('sample', 'percent.mt', 'nCount_RNA', 'cell_guide_count'))

# %%
Pseudo_bulk_exp = AverageExpression(tRF_seuratobj, assays = "RNA", group.by = "guide", slot = "data")
Pseudo_bulk_exp = Pseudo_bulk_exp[['RNA']]

Pseudo_bulk_exp_counts = AverageExpression(tRF_seuratobj, assays = "RNA", group.by = "guide", slot = "counts")
Pseudo_bulk_exp_counts = Pseudo_bulk_exp_counts[['RNA']]

# %%
Pseudo_bulk_exp_RC = AverageExpression(tRF_seuratobj_rel_norlmalized, assays = "RNA", group.by = "guide", slot = "data")
Pseudo_bulk_exp_RC = Pseudo_bulk_exp_RC[['RNA']]
# Out:
# Warning message in PseudobulkExpression(object = object, pb.method = "average", :
# “Exponentiation yielded infinite values. `data` may not be log-normed.”

# %%
GS.hallmark <- getGeneSets(library = "H")
GS.hallmark = geneIds(GS.hallmark)

# %%
genes_present_in_set = vector(length = length(GS.hallmark))
for (i in 1:length(GS.hallmark)){
    genes_present_in_set[i] = length(which(GS.hallmark[[i]] %in% rownames(Pseudo_bulk_exp)))
}

geneset_gene_counts_df = data.frame(gene_set = names(GS.hallmark), genes_present = genes_present_in_set)

# %%
suppressMessages(library(dplyr))
geneset_gene_counts_df %>% arrange(genes_present) %>% head()
# Out:
#   gene_set                            genes_present
# 1 HALLMARK_PANCREAS_BETA_CELLS        28
# 2 HALLMARK_ANGIOGENESIS               31
# 3 HALLMARK_NOTCH_SIGNALING            31
# 4 HALLMARK_HEDGEHOG_SIGNALING         34
# 5 HALLMARK_APICAL_SURFACE             38
# 6 HALLMARK_WNT_BETA_CATENIN_SIGNALING 39

# %% [markdown]
# ## Heatmaps of gene set expression

# %%
genesetexp_x_guide = matrix(0, nrow = length(GS.hallmark), ncol = ncol(Pseudo_bulk_exp), dimnames = list(names(GS.hallmark), colnames(Pseudo_bulk_exp)))

for (j in 1:ncol(Pseudo_bulk_exp)){
    for (i in 1:length(GS.hallmark)){
        genes = GS.hallmark[[i]][GS.hallmark[[i]] %in% rownames(Pseudo_bulk_exp)]
        genesetexp_x_guide[i,j] = mean(Pseudo_bulk_exp[genes,j])
    }
}

# %%
mean(range(genesetexp_x_guide))
# Out:
# [1] 4.333373

# %%
suppressMessages(library(ComplexHeatmap))
suppressMessages(library(gridExtra))

avg = mean(genesetexp_x_guide)
lower_bound = mean(genesetexp_x_guide) - 2*sd(genesetexp_x_guide)
upper_bound = mean(genesetexp_x_guide) + 2*sd(genesetexp_x_guide)

coloring_map <- circlize::colorRamp2(c(lower_bound, avg, upper_bound), c("blue", "white", "red"))

perturb_htmp <- function(matrix, title) {
  draw(Heatmap(matrix, name = title, show_column_names = TRUE, show_row_names = TRUE, show_column_dend = TRUE,
               col = coloring_map, show_row_dend = TRUE, use_raster = TRUE, row_title = 'Gene Sets', 
               column_title = 'Perturbations', row_title_side = 'left', column_title_side = 'top', 
               column_names_gp = gpar(fontsize = 2), row_names_gp = gpar(fontsize = 5)))
}

options(repr.plot.width = 14, repr.plot.height = 10)

pdf('/home/ssobti/projects/mir_tud/output_data/genexp_pathway/pseudobulk_hallmark_htmap_tRF.pdf', width = 12, height = 11)
perturb_htmp(genesetexp_x_guide, 'Pseudo-bulk')
dev.off()

perturb_htmp(genesetexp_x_guide, 'Pseudo-bulk')
# Out:
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# png
#   2
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# plot without title

# %%
## better heatmap (using pheatmap and better color scheme)
coldat = cbind(guide = colnames(Pseudo_bulk_exp_counts), t(genesetexp_x_guide))
coldat = as.data.frame(coldat)
rownames(coldat) = colnames(Pseudo_bulk_exp_counts)
coldat[, 2:ncol(coldat)] <- apply(coldat[, -1], 2, as.numeric)

bulkSE <- SummarizedExperiment(assays = list(counts = Pseudo_bulk_exp_counts,
             logcounts = Pseudo_bulk_exp), colData = coldat)

colors <- colorRampPalette(c("#0D0887FF","#7E03A8FF","#CC4678FF","#F89441FF","#F0F921FF"))
options(repr.plot.width = 16, repr.plot.height = 10)


htmp = dittoHeatmap(bulkSE, genes = NULL, metas = as.character(rownames(genesetexp_x_guide)), 
             annot.by = "guide", order.by = "guide", 
             fontsize = 7, 
             cluster_cols = TRUE,
             heatmap.colors = colors(50))

htmp
# Out:
# plot without title

# %%
save_pheatmap_pdf <- function(x, filename, width=30, height=12) {
   stopifnot(!missing(x))
   stopifnot(!missing(filename))
   pdf(filename, width=width, height=height)
   grid::grid.newpage()
   grid::grid.draw(x$gtable)
   dev.off()
}

save_pheatmap_pdf(htmp, "/home/ssobti/projects/mir_tud/output_data/genexp_pathway/pseudobulk_hallmark_htmap2_tRF.pdf")
# Out:
# png
#   2

# %% [markdown]
# ## Heatmaps of gene set fold change expression to TuD_NC

# %%
class(genesetexp_x_guide)
# Out:
# [1] "matrix" "array"

# %%
tmp_df = as.data.frame(genesetexp_x_guide)
genesetexp_x_guide_FC = tmp_df
for (i in 1:ncol(tmp_df)){
    genesetexp_x_guide_FC[,i] = tmp_df[,i]/tmp_df[,'TuD_NC']
}

genesetexp_x_guide_FC = as.matrix(genesetexp_x_guide_FC)

# %%
range(genesetexp_x_guide_FC)
# Out:
# [1] 0.4454264 3.8086815

# %%
suppressMessages(library(ComplexHeatmap))
suppressMessages(library(gridExtra))

avg = mean(genesetexp_x_guide_FC)
lower_bound = mean(genesetexp_x_guide_FC) - 2*sd(genesetexp_x_guide_FC)
upper_bound = mean(genesetexp_x_guide_FC) + 2*sd(genesetexp_x_guide_FC)

coloring_map <- circlize::colorRamp2(c(lower_bound, avg, upper_bound), c("blue", "white", "red"))

perturb_htmp <- function(matrix, title) {
  draw(Heatmap(matrix, name = title, show_column_names = TRUE, show_row_names = TRUE, show_column_dend = TRUE,
               col = coloring_map, show_row_dend = TRUE, use_raster = TRUE, row_title = 'Gene Sets', 
               column_title = 'Perturbations', row_title_side = 'left', column_title_side = 'top', 
               column_names_gp = gpar(fontsize = 2), row_names_gp = gpar(fontsize = 5)))
}

pdf('/home/ssobti/projects/mir_tud/output_data/genexp_pathway/pseudobulk_foldchange_hallmark_htmap_tRF.pdf', width = 12, height = 11)
perturb_htmp(genesetexp_x_guide_FC, 'Fold Change Pseudo-bulk')
dev.off()

perturb_htmp(genesetexp_x_guide_FC, 'Fold Change Pseudo-bulk')
# Out:
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# png
#   2
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# plot without title

# %%
## better heatmap (using pheatmap and better color scheme)
coldat = cbind(guide = colnames(Pseudo_bulk_exp_counts), t(genesetexp_x_guide_FC))
coldat = as.data.frame(coldat)
rownames(coldat) = colnames(Pseudo_bulk_exp_counts)
coldat[, 2:ncol(coldat)] <- apply(coldat[, -1], 2, as.numeric)

bulkSE2 <- SummarizedExperiment(assays = list(counts = Pseudo_bulk_exp_counts,
             logcounts = Pseudo_bulk_exp), colData = coldat)

colors <- colorRampPalette(c("#0D0887FF","#7E03A8FF","#CC4678FF","#F89441FF","#F0F921FF"))
options(repr.plot.width = 16, repr.plot.height = 10)


htmp = dittoHeatmap(bulkSE2, genes = NULL, metas = as.character(rownames(genesetexp_x_guide_FC)), 
             annot.by = "guide", order.by = "guide", assay = 'logcounts',
             fontsize = 7, 
             cluster_cols = TRUE,
             heatmap.colors = colors(50))

htmp
# Out:
# plot without title

# %%
### try averaging addmodule score across guides for each module and create heatmap

# %%
dittoHeatmap(bulkSE,
             annot.by = "guide", order.by = "guide", 
             fontsize = 7, 
             cluster_cols = TRUE,
             heatmap.colors = colors(50))
# Out:
# plot without title

# %%
coldat
# Out:
#                        guide                  HALLMARK_ADIPOGENESIS
# tRF_Ala_AGC_2          tRF_Ala_AGC_2          1.0054654
# tRF_Ala_AGC.TGC_2      tRF_Ala_AGC.TGC_2      0.9878022
# tRF_Ala_CGC_2          tRF_Ala_CGC_2          0.9976959
# tRF_Ala_CGC.AGC.TGC_5  tRF_Ala_CGC.AGC.TGC_5  1.0037672
# tRF_Ala_TGC_2          tRF_Ala_TGC_2          0.9847373
# tRF_Ala_TGC.AGC_2      tRF_Ala_TGC.AGC_2      1.0283189
# tRF_Ala_TGC.AGC_6      tRF_Ala_TGC.AGC_6      1.0044922
# tRF_Arg_ACG_2          tRF_Arg_ACG_2          1.0026619
# tRF_Arg_CCG.CCT_3      tRF_Arg_CCG.CCT_3      1.0098896
# tRF_Arg_CCT_2          tRF_Arg_CCT_2          1.0076853
# tRF_Arg_CCT_3          tRF_Arg_CCT_3          0.9992265
# tRF_Arg_TCG_2          tRF_Arg_TCG_2          1.0103303
# tRF_Arg_TCG.CCG_2      tRF_Arg_TCG.CCG_2      1.0023658
# tRF_Arg_TCT_2          tRF_Arg_TCT_2          0.9943907
# tRF_Arg_TCT_4          tRF_Arg_TCT_4          1.0096728
# tRF_Asn_GTT_2          tRF_Asn_GTT_2          0.9974988
# tRF_Asp_GTC_2          tRF_Asp_GTC_2          0.9781577
# tRF_Cys.Ala_GCA.AGC_3  tRF_Cys.Ala_GCA.AGC_3  1.0046991
# tRF_Gln_CTG_2          tRF_Gln_CTG_2          1.0115526
# tRF_Gln_CTG.TTG_2      tRF_Gln_CTG.TTG_2      1.0000229
# tRF_Gln_TTG.CTG_2      tRF_Gln_TTG.CTG_2      1.0455367
# tRF_Glu_CTC_2          tRF_Glu_CTC_2          1.0083128
# tRF_Glu_TTC_2          tRF_Glu_TTC_2          1.0012790
# tRF_Glu_TTC_4          tRF_Glu_TTC_4          1.0005142
# tRF_Gly_CCC_2          tRF_Gly_CCC_2          1.0037588
# tRF_Gly_GCC_2          tRF_Gly_GCC_2          0.9994249
# tRF_Gly_GCC.CCC_4      tRF_Gly_GCC.CCC_4      0.9952688
# tRF_Gly_TCC_2          tRF_Gly_TCC_2          1.0230696
# tRF_Gly_TCC_4          tRF_Gly_TCC_4          0.9992074
# tRF_His_GTG_2          tRF_His_GTG_2          1.0221104
# ⋮                      ⋮                      ⋮
# tRNA-Thr-CGT-3-1.2t    tRNA-Thr-CGT-3-1.2t    0.9930748
# tRNA-Thr-CGT-3-1.lh    tRNA-Thr-CGT-3-1.lh    0.9784592
# tRNA-Thr-CGT-4-1.1t    tRNA-Thr-CGT-4-1.1t    0.9931039
# tRNA-Thr-CGT-4-1.2t    tRNA-Thr-CGT-4-1.2t    1.0107364
# tRNA-Thr-CGT-4-1.3t    tRNA-Thr-CGT-4-1.3t    1.0010707
# tRNA-Thr-CGT-4-1.lh    tRNA-Thr-CGT-4-1.lh    1.0289852
# tRNA-Thr-CGT-4-1.rh    tRNA-Thr-CGT-4-1.rh    0.9855681
# tRNA-Thr-TGT-2-1.lh    tRNA-Thr-TGT-2-1.lh    0.9934320
# tRNA-Thr-TGT-3-1.lh    tRNA-Thr-TGT-3-1.lh    0.9916107
# tRNA-Thr-TGT-5-1.1t    tRNA-Thr-TGT-5-1.1t    1.1089156
# tRNA-Thr-TGT-5-1.lh    tRNA-Thr-TGT-5-1.lh    1.0033280
# tRNA-Trp-CCA-2-1.3t    tRNA-Trp-CCA-2-1.3t    1.0101243
# tRNA-Trp-CCA-2-1.rh    tRNA-Trp-CCA-2-1.rh    0.9847770
# tRNA-Trp-CCA-4-1.3t    tRNA-Trp-CCA-4-1.3t    1.0065834
# tRNA-Trp-CCA-4-1.rh    tRNA-Trp-CCA-4-1.rh    0.9825772
# tRNA-Tyr-GTA-2-1.2t    tRNA-Tyr-GTA-2-1.2t    1.0286449
# tRNA-Tyr-GTA-2-1.lh    tRNA-Tyr-GTA-2-1.lh    0.9713362
# tRNA-Val-AAC-3-1.2t    tRNA-Val-AAC-3-1.2t    0.9800237
# tRNA-Val-AAC-3-1.3t    tRNA-Val-AAC-3-1.3t    0.9624541
# tRNA-Val-AAC-3-1.rh    tRNA-Val-AAC-3-1.rh    1.0191222
# tRNA-Val-CAC-(6)1-1.3t tRNA-Val-CAC-(6)1-1.3t 1.0502564
# tRNA-Val-CAC-(6)1-1.rh tRNA-Val-CAC-(6)1-1.rh 1.0062652
# tRNA-Val-CAC-2-1.3t    tRNA-Val-CAC-2-1.3t    1.1469283
# tRNA-Val-CAC-2-1.rh    tRNA-Val-CAC-2-1.rh    0.9889956
# tRNA-Val-CAC-3-1.3t    tRNA-Val-CAC-3-1.3t    0.9070679
# tRNA-Val-CAC-3-1.rh    tRNA-Val-CAC-3-1.rh    1.0070776
# tRNA-Val-CAC-6-1.3t    tRNA-Val-CAC-6-1.3t    0.8360900
# tRNA-Val-CAC-6-1.rh    tRNA-Val-CAC-6-1.rh    1.0236895
# tRNA-Val-TAC-(2)1-1.2t tRNA-Val-TAC-(2)1-1.2t 0.9866169
# TuD_NC                 TuD_NC                 1.0000000
#                        HALLMARK_ALLOGRAFT_REJECTION HALLMARK_ANDROGEN_RESPONSE
# tRF_Ala_AGC_2          1.0037112                    1.0007229
# tRF_Ala_AGC.TGC_2      1.0499577                    0.9764439
# tRF_Ala_CGC_2          0.9601636                    0.9983004
# tRF_Ala_CGC.AGC.TGC_5  0.9965221                    0.9998570
# tRF_Ala_TGC_2          1.0036190                    0.9762002
# tRF_Ala_TGC.AGC_2      1.0407455                    0.9504030
# tRF_Ala_TGC.AGC_6      1.0013971                    1.0062885
# tRF_Arg_ACG_2          1.0122864                    0.9977225
# tRF_Arg_CCG.CCT_3      0.9818127                    0.9831864
# tRF_Arg_CCT_2          1.0118046                    1.0103485
# tRF_Arg_CCT_3          1.0028566                    1.0178972
# tRF_Arg_TCG_2          0.9976705                    0.9948648
# tRF_Arg_TCG.CCG_2      1.0138553                    1.0058526
# tRF_Arg_TCT_2          1.0061627                    0.9960289
# tRF_Arg_TCT_4          0.9932838                    1.0138304
# tRF_Asn_GTT_2          1.0065491                    0.9990709
# tRF_Asp_GTC_2          1.0049230                    1.0367366
# tRF_Cys.Ala_GCA.AGC_3  0.9986933                    1.0004521
# tRF_Gln_CTG_2          1.0144102                    1.0024380
# tRF_Gln_CTG.TTG_2      1.0077499                    0.9911936
# tRF_Gln_TTG.CTG_2      1.0307482                    0.9567203
# tRF_Glu_CTC_2          1.0105623                    0.9860693
# tRF_Glu_TTC_2          1.0032571                    0.9999201
# tRF_Glu_TTC_4          0.9963219                    1.0023273
# tRF_Gly_CCC_2          1.0057228                    0.9968371
# tRF_Gly_GCC_2          1.0023259                    0.9865905
# tRF_Gly_GCC.CCC_4      0.9890897                    1.0012289
# tRF_Gly_TCC_2          1.0323576                    1.0163376
# tRF_Gly_TCC_4          0.9999417                    1.0010940
# tRF_His_GTG_2          0.9796170                    0.9922331
# ⋮                      ⋮                            ⋮
# tRNA-Thr-CGT-3-1.2t    0.9626514                    1.0096714
# tRNA-Thr-CGT-3-1.lh    0.9962258                    0.9760606
# tRNA-Thr-CGT-4-1.1t    0.9787772                    0.9690080
# tRNA-Thr-CGT-4-1.2t    1.0130163                    0.9960749
# tRNA-Thr-CGT-4-1.3t    1.0019754                    1.0030443
# tRNA-Thr-CGT-4-1.lh    1.0054231                    0.9904639
# tRNA-Thr-CGT-4-1.rh    1.0118185                    1.0126371
# tRNA-Thr-TGT-2-1.lh    1.0281416                    1.0106192
# tRNA-Thr-TGT-3-1.lh    1.0180068                    0.9905535
# tRNA-Thr-TGT-5-1.1t    0.9793888                    1.0029458
# tRNA-Thr-TGT-5-1.lh    1.0009282                    1.0000136
# tRNA-Trp-CCA-2-1.3t    1.0988634                    1.0455719
# tRF_Arg_TCT_2          1.0152183
# tRF_Arg_TCT_4          1.0227877
# tRF_Asn_GTT_2          0.9876158
# tRF_Asp_GTC_2          1.0082052
# tRF_Cys.Ala_GCA.AGC_3  0.9904789
# tRF_Gln_CTG_2          1.0078290
# tRF_Gln_CTG.TTG_2      0.9924341
# tRF_Gln_TTG.CTG_2      0.9295739
# tRF_Glu_CTC_2          0.9872989
# tRF_Glu_TTC_2          1.0158593
# tRF_Glu_TTC_4          1.0029502
# tRF_Gly_CCC_2          1.0023064
# tRF_Gly_GCC_2          0.9919436
# tRF_Gly_GCC.CCC_4      1.0109683
# tRF_Gly_TCC_2          1.0059508
# tRF_Gly_TCC_4          1.0029395
# tRF_His_GTG_2          1.0076152
# ⋮                      ⋮
# tRNA-Thr-CGT-3-1.2t    0.9786912
# tRNA-Thr-CGT-3-1.lh    1.0373423
# tRNA-Thr-CGT-4-1.1t    1.0190147
# tRNA-Thr-CGT-4-1.2t    1.0080165
# tRNA-Thr-CGT-4-1.3t    0.9733926
# tRNA-Thr-CGT-4-1.lh    1.0143537
# tRNA-Thr-CGT-4-1.rh    0.9851221
# tRNA-Thr-TGT-2-1.lh    1.0107331
# tRNA-Thr-TGT-3-1.lh    0.9947839
# tRNA-Thr-TGT-5-1.1t    1.0124376
# tRNA-Thr-TGT-5-1.lh    0.9974004
# tRNA-Trp-CCA-2-1.3t    1.0993828
# tRNA-Trp-CCA-2-1.rh    1.0149801
# tRNA-Trp-CCA-4-1.3t    0.9798214
# tRNA-Trp-CCA-4-1.rh    1.0314070
# tRNA-Tyr-GTA-2-1.2t    1.0367919
# tRNA-Tyr-GTA-2-1.lh    0.9943970
# tRNA-Val-AAC-3-1.2t    1.0031008
# tRNA-Val-AAC-3-1.3t    0.8836284
# tRNA-Val-AAC-3-1.rh    0.9926587
# tRNA-Val-CAC-(6)1-1.3t 1.0172178
# tRNA-Val-CAC-(6)1-1.rh 0.9963307
# tRNA-Val-CAC-2-1.3t    1.5029446
# tRNA-Val-CAC-2-1.rh    1.0329473
# tRNA-Val-CAC-3-1.3t    0.8797721
# tRNA-Val-CAC-3-1.rh    0.9896569
# tRNA-Val-CAC-6-1.3t    1.1535395
# tRNA-Val-CAC-6-1.rh    1.0370441
# tRNA-Val-TAC-(2)1-1.2t 1.0053027
# TuD_NC                 1.0000000
#                        HALLMARK_CHOLESTEROL_HOMEOSTASIS ⋯
# tRF_Ala_AGC_2          1.0078481                        ⋯
# tRF_Ala_AGC.TGC_2      1.0626026                        ⋯
# tRF_Ala_CGC_2          1.0038786                        ⋯
# tRF_Ala_CGC.AGC.TGC_5  0.9972776                        ⋯
# tRF_Ala_TGC_2          0.9847083                        ⋯
# tRF_Ala_TGC.AGC_2      1.0702482                        ⋯
# tRF_Ala_TGC.AGC_6      1.0019922                        ⋯
# tRF_Arg_ACG_2          1.0070056                        ⋯
# tRF_Arg_CCG.CCT_3      1.0029227                        ⋯
# tRF_Arg_CCT_2          1.0197719                        ⋯
# tRF_Arg_CCT_3          0.9953186                        ⋯
# tRF_Arg_TCG_2          1.0075934                        ⋯
# tRF_Arg_TCG.CCG_2      1.0072663                        ⋯
# tRF_Arg_TCT_2          1.0026391                        ⋯
# tRF_Arg_TCT_4          1.0012327                        ⋯
# tRF_Asn_GTT_2          1.0021060                        ⋯
# tRF_Asp_GTC_2          1.0026353                        ⋯
# tRF_Cys.Ala_GCA.AGC_3  1.0010063                        ⋯
# tRF_Gln_CTG_2          1.0046872                        ⋯
# tRF_Gln_CTG.TTG_2      0.9990113                        ⋯
# tRF_Gln_TTG.CTG_2      1.0351115                        ⋯
# tRF_Glu_CTC_2          1.0039045                        ⋯
# tRF_Glu_TTC_2          1.0009317                        ⋯
# tRF_Glu_TTC_4          1.0020569                        ⋯
# tRF_Gly_CCC_2          0.9905236                        ⋯
# tRF_Gly_GCC_2          0.9935063                        ⋯
# tRF_Gly_GCC.CCC_4      0.9872440                        ⋯
# tRF_Gly_TCC_2          1.0160456                        ⋯
# tRF_Gly_TCC_4          1.0003793                        ⋯
# tRF_His_GTG_2          0.9907075                        ⋯
# ⋮                      ⋮                                ⋱
# tRNA-Thr-CGT-3-1.2t    0.9726416                        ⋯
# tRNA-Thr-CGT-3-1.lh    1.0102711                        ⋯
# tRNA-Thr-CGT-4-1.1t    1.0498850                        ⋯
# tRNA-Thr-CGT-4-1.2t    0.9760579                        ⋯
# tRNA-Thr-CGT-4-1.3t    0.8997561                        ⋯
# tRNA-Thr-CGT-4-1.lh    1.0117063                        ⋯
# tRNA-Thr-CGT-4-1.rh    0.9979196                        ⋯
# tRNA-Thr-TGT-2-1.lh    1.0230393                        ⋯
# tRNA-Thr-TGT-3-1.lh    0.9932313                        ⋯
# tRNA-Thr-TGT-5-1.1t    1.0179876                        ⋯
# tRNA-Thr-TGT-5-1.lh    0.9971245                        ⋯
# tRNA-Trp-CCA-2-1.3t    1.0504031                        ⋯
# tRNA-Trp-CCA-2-1.rh    1.0136061                        ⋯
# tRNA-Trp-CCA-4-1.3t    1.0400284                        ⋯
# tRNA-Trp-CCA-4-1.rh    1.0056660                        ⋯
# tRNA-Tyr-GTA-2-1.2t    1.0155781                        ⋯
# tRNA-Tyr-GTA-2-1.lh    0.9772499                        ⋯
# tRNA-Val-AAC-3-1.2t    1.0270218                        ⋯
# tRNA-Val-AAC-3-1.3t    0.9952965                        ⋯
# tRNA-Val-AAC-3-1.rh    1.0357700                        ⋯
# tRNA-Val-CAC-(6)1-1.3t 0.9744524                        ⋯
# tRNA-Val-CAC-(6)1-1.rh 0.9741222                        ⋯
# tRNA-Val-CAC-2-1.3t    0.9669358                        ⋯
# tRNA-Val-CAC-2-1.rh    0.9828266                        ⋯
# tRNA-Val-CAC-3-1.3t    0.9102123                        ⋯
# tRNA-Val-CAC-3-1.rh    1.0030705                        ⋯
# tRNA-Val-CAC-6-1.3t    0.9746343                        ⋯
# tRNA-Val-CAC-6-1.rh    1.0219859                        ⋯
# tRNA-Val-TAC-(2)1-1.2t 0.9688588                        ⋯
# TuD_NC                 1.0000000                        ⋯
#                        HALLMARK_PROTEIN_SECRETION
# tRF_Ala_AGC_2          0.9965536
# tRF_Ala_AGC.TGC_2      1.0206898
# tRF_Ala_CGC_2          1.0031856
# tRF_Arg_CCT_2          0.9996811                0.9831001
# tRF_Arg_CCT_3          1.0034342                1.0064280
# tRF_Arg_TCG_2          1.0062769                1.0069526
# tRF_Arg_TCG.CCG_2      1.0135216                1.0053147
# tRF_Arg_TCT_2          1.0066044                0.9739872
# tRF_Arg_TCT_4          0.9539185                0.9992022
# tRF_Asn_GTT_2          0.9981862                0.9989096
# tRF_Asp_GTC_2          1.0109803                1.0565168
# tRF_Cys.Ala_GCA.AGC_3  0.9980478                0.9928554
# tRF_Gln_CTG_2          0.9820320                0.9746796
# tRF_Gln_CTG.TTG_2      1.0187495                0.9852374
# tRF_Gln_TTG.CTG_2      1.0644745                0.8946037
# tRF_Glu_CTC_2          0.9923877                0.9836263
# tRF_Glu_TTC_2          0.9869758                1.0214205
# tRF_Glu_TTC_4          1.0269484                1.0052507
# tRF_Gly_CCC_2          1.0314964                1.0017454
# tRF_Gly_GCC_2          0.9988450                0.9865209
# tRF_Gly_GCC.CCC_4      0.9883459                0.9975925
# tRF_Gly_TCC_2          0.9785454                0.9718618
# tRF_Gly_TCC_4          1.0019355                0.9783773
# tRF_His_GTG_2          1.0184880                1.0024559
# ⋮                      ⋮                        ⋮
# tRNA-Thr-CGT-3-1.2t    1.0238083                1.0510384
# tRNA-Thr-CGT-3-1.lh    1.0017173                1.0122179
# tRNA-Thr-CGT-4-1.1t    1.0047408                0.9386639
# tRNA-Thr-CGT-4-1.2t    1.0139501                1.0215680
# tRNA-Thr-CGT-4-1.3t    1.1420357                0.9204345
# tRNA-Thr-CGT-4-1.lh    1.0176280                1.0050281
# tRNA-Thr-CGT-4-1.rh    1.0783497                0.9677961
# tRNA-Thr-TGT-2-1.lh    0.9700441                0.9637144
# tRNA-Thr-TGT-3-1.lh    1.0274554                0.9568873
# tRNA-Thr-TGT-5-1.1t    0.9925856                1.0335428
# tRNA-Thr-TGT-5-1.lh    0.9699167                1.0032891
# tRNA-Trp-CCA-2-1.3t    0.9790237                1.0050170
# tRNA-Trp-CCA-2-1.rh    0.9494249                1.0188642
# tRNA-Trp-CCA-4-1.3t    1.0825634                0.9218854
# tRNA-Trp-CCA-4-1.rh    0.9886488                1.0483714
# tRNA-Tyr-GTA-2-1.2t    1.0143388                1.0144485
# tRNA-Tyr-GTA-2-1.lh    1.0183384                0.9915196
# tRNA-Val-AAC-3-1.2t    1.0249267                0.9961381
# tRNA-Val-AAC-3-1.3t    1.1465145                0.4756225
# tRNA-Val-AAC-3-1.rh    0.9993545                0.9325367
# tRNA-Val-CAC-(6)1-1.3t 1.1469431                0.9657800
# tRNA-Val-CAC-(6)1-1.rh 1.0632773                1.0074063
# tRNA-Val-CAC-2-1.3t    1.0276461                1.2896185
# tRNA-Val-CAC-2-1.rh    1.0131504                1.0053621
# tRNA-Val-CAC-3-1.3t    0.9836883                1.5149485
# tRNA-Val-CAC-3-1.rh    1.0420974                1.0624466
# tRNA-Val-CAC-6-1.3t    1.0504170                1.2433693
# tRNA-Val-CAC-6-1.rh    0.9528668                1.0199994
# tRNA-Val-TAC-(2)1-1.2t 0.9016644                1.1038608
# TuD_NC                 1.0000000                1.0000000
#                        HALLMARK_TNFA_SIGNALING_VIA_NFKB
# tRF_Ala_AGC_2          1.0124675
# tRF_Ala_AGC.TGC_2      1.0864654
# tRF_Ala_CGC_2          1.0164295
# tRF_Ala_CGC.AGC.TGC_5  1.0094658
# tRF_Ala_TGC_2          0.9754455
# tRF_Ala_TGC.AGC_2      0.8781775
# tRF_Ala_TGC.AGC_6      1.0042757
# tRF_Arg_ACG_2          0.9863754
# tRF_Arg_CCG.CCT_3      0.9718070
# tRF_Arg_CCT_2          0.9909211
# tRF_Arg_CCT_3          1.0098861
# tRF_Arg_TCG_2          1.0269156
# tRF_Arg_TCG.CCG_2      1.0250707
# tRF_Arg_TCT_2          0.9804378
# tRF_Arg_TCT_4          1.0031521
# tRF_Asn_GTT_2          0.9987862
# tRF_Asp_GTC_2          1.0010046
# tRF_Cys.Ala_GCA.AGC_3  1.0053903
# tRF_Gln_CTG_2          1.0121195
# tRF_Gln_CTG.TTG_2      0.9876808
# tRF_Gln_TTG.CTG_2      1.0287827
# tRF_Glu_CTC_2          0.9848056
# tRF_Glu_TTC_2          1.0055680
# tRF_Glu_TTC_4          0.9968874
# tRF_Gly_CCC_2          0.9938233
# tRF_Gly_GCC_2          1.0108164
# tRF_Gly_GCC.CCC_4      1.0141705
# tRF_Gly_TCC_2          0.9959046
# tRF_Gly_TCC_4          0.9960021
# tRF_His_GTG_2          1.0296811
# ⋮                      ⋮
# tRNA-Thr-CGT-3-1.2t    1.0576008
# tRNA-Thr-CGT-3-1.lh    0.9652662
# tRNA-Thr-CGT-4-1.1t    0.9939262
# tRNA-Thr-CGT-4-1.2t    0.9647491
# tRNA-Thr-CGT-4-1.3t    0.9762655
# tRNA-Thr-CGT-4-1.lh    1.0124016
# tRNA-Thr-CGT-4-1.rh    1.0289291
# tRNA-Thr-TGT-2-1.lh    0.9914355
# tRNA-Thr-TGT-3-1.lh    0.9901247
# tRNA-Thr-TGT-5-1.1t    1.1282964
# tRNA-Thr-TGT-5-1.lh    1.0026593
# tRNA-Trp-CCA-2-1.3t    1.1520354
# tRNA-Trp-CCA-2-1.rh    1.0252618
# tRNA-Trp-CCA-4-1.3t    0.9864080
# tRNA-Trp-CCA-4-1.rh    1.0500788
# tRNA-Tyr-GTA-2-1.2t    0.9877703
# tRNA-Tyr-GTA-2-1.lh    0.9885706
# tRNA-Val-AAC-3-1.2t    0.9957498
# tRNA-Val-AAC-3-1.3t    0.6262845
# tRNA-Val-AAC-3-1.rh    0.9663592
# tRNA-Val-CAC-(6)1-1.3t 0.9680778
# tRNA-Val-CAC-(6)1-1.rh 0.9953639
# tRNA-Val-CAC-2-1.3t    1.7926074
# tRNA-Val-CAC-2-1.rh    0.9926497
# tRNA-Val-CAC-3-1.3t    0.8191752
# tRNA-Val-CAC-3-1.rh    1.0817873
# tRNA-Val-CAC-6-1.3t    0.9943757
# tRNA-Val-CAC-6-1.rh    0.9912894
# tRNA-Val-TAC-(2)1-1.2t 0.9756659
# TuD_NC                 1.0000000
#                        HALLMARK_UNFOLDED_PROTEIN_RESPONSE
# tRF_Ala_AGC_2          1.0061165
# tRF_Ala_AGC.TGC_2      1.0931004
# tRF_Ala_CGC_2          0.9788698
# tRF_Ala_CGC.AGC.TGC_5  1.0023848
# tRF_Ala_TGC_2          0.9969548
# tRF_Ala_TGC.AGC_2      1.0303978
# tRF_Ala_TGC.AGC_6      0.9970400
# tRF_Arg_ACG_2          1.0124061
# tRF_Arg_CCG.CCT_3      0.9948970
# tRF_Arg_CCT_2          1.0121272
# tRF_Arg_CCT_3          0.9860721
# tRF_Arg_TCG_2          1.0142391
# tRF_Arg_TCG.CCG_2      1.0094543
# tRF_Arg_TCT_2          0.9831724
# tRF_Arg_TCT_4          0.9852300
# tRF_Asn_GTT_2          0.9955686
# tRF_Asp_GTC_2          1.0025071
# tRF_Cys.Ala_GCA.AGC_3  1.0042420
# tRF_Gln_CTG_2          1.0136563
# tRF_Gln_CTG.TTG_2      0.9978438
# tRF_Gln_TTG.CTG_2      1.0672475
# tRF_Glu_CTC_2          0.9994162
# tRF_Glu_TTC_2          1.0004349
# tRF_Glu_TTC_4          1.0139365
# tRF_Gly_CCC_2          1.0097566
# tRF_Gly_GCC_2          0.9994508
# tRF_Gly_GCC.CCC_4      0.9953073
# tRF_Gly_TCC_2          1.0170739
# tRF_Gly_TCC_4          0.9835793
# tRF_His_GTG_2          0.9914279
# ⋮                      ⋮
# tRNA-Thr-CGT-3-1.2t    0.9839858
# tRNA-Thr-CGT-3-1.lh    0.9951779
# tRNA-Thr-CGT-4-1.1t    1.0253979
# tRNA-Thr-CGT-4-1.2t    0.9954963
# tRNA-Thr-CGT-4-1.3t    1.1382006
# tRNA-Thr-CGT-4-1.lh    1.0210023
# tRNA-Thr-CGT-4-1.rh    1.0090948
# tRNA-Thr-TGT-2-1.lh    0.9900982
# tRNA-Thr-TGT-3-1.lh    1.0024297
# tRNA-Thr-TGT-5-1.1t    1.0391595
# tRNA-Thr-TGT-5-1.lh    0.9824143
# tRNA-Trp-CCA-2-1.3t    1.0029831
# tRNA-Trp-CCA-2-1.rh    0.9713640
# tRNA-Trp-CCA-4-1.3t    1.0549172
# tRNA-Trp-CCA-4-1.rh    0.9547363
# tRNA-Tyr-GTA-2-1.2t    1.0018923
# tRNA-Tyr-GTA-2-1.lh    0.9784204
# tRNA-Val-AAC-3-1.2t    1.0077880
# tRNA-Val-AAC-3-1.3t    1.2219087
# tRNA-Val-AAC-3-1.rh    1.0155581
# tRNA-Val-CAC-(6)1-1.3t 0.9877981
# tRNA-Val-CAC-(6)1-1.rh 1.0249851
# tRNA-Val-CAC-2-1.3t    0.9485131
# tRNA-Val-CAC-2-1.rh    0.9848051
# tRNA-Val-CAC-3-1.3t    1.0106224
# tRNA-Val-CAC-3-1.rh    0.9796300
# tRNA-Val-CAC-6-1.3t    0.8762992
# tRNA-Val-CAC-6-1.rh    1.0089722
# tRNA-Val-TAC-(2)1-1.2t 0.9675612
# TuD_NC                 1.0000000
#                        HALLMARK_UV_RESPONSE_DN HALLMARK_UV_RESPONSE_UP
# tRF_Ala_AGC_2          1.0007322               0.9914437
# tRF_Ala_AGC.TGC_2      1.0508814               1.0807975
# tRF_Ala_CGC_2          0.9865636               1.0086250
# tRF_Ala_CGC.AGC.TGC_5  0.9932837               1.0112235
# tRF_Ala_TGC_2          0.9887765               0.9551097
# tRF_Ala_TGC.AGC_2      0.9360487               0.9356140
# tRF_Ala_TGC.AGC_6      0.9967639               0.9958631
# tRF_Arg_ACG_2          0.9939034               1.0090218
# tRF_Arg_CCG.CCT_3      0.9779668               0.9863932
# tRF_Arg_CCT_2          0.9879245               1.0090454
# tRF_Arg_CCT_3          1.0073585               0.9956354
# tRF_Arg_TCG_2          0.9710535               1.0285958
# tRF_Arg_TCG.CCG_2      0.9947608               1.0142574
# tRF_Arg_TCT_2          0.9975589               0.9891443
# tRF_Arg_TCT_4          0.9920194               0.9925831
# tRF_Asn_GTT_2          0.9891048               1.0038172
# tRF_Asp_GTC_2          1.0656370               1.0047318
# tRF_Cys.Ala_GCA.AGC_3  1.0004921               1.0065337
# tRF_Gln_CTG_2          0.9859609               1.0077965
# tRF_Gln_CTG.TTG_2      0.9954253               0.9980166
# tRF_Gln_TTG.CTG_2      0.9398638               1.1023634
# tRF_Glu_CTC_2          0.9815662               1.0044291
# tRF_Glu_TTC_2          1.0048585               0.9918141
# tRF_Glu_TTC_4          0.9812911               1.0072449
# tRF_Gly_CCC_2          0.9928946               1.0087194
# tRF_Gly_GCC_2          0.9832392               1.0067559
# tRF_Gly_GCC.CCC_4      0.9948938               0.9899412
# tRF_Gly_TCC_2          0.9624979               0.9838169
# tRF_Gly_TCC_4          0.9804895               1.0046515
# tRF_His_GTG_2          0.9820570               1.0071220
# ⋮                      ⋮                       ⋮
# tRNA-Thr-CGT-3-1.2t    1.0117042               1.0382252
# tRNA-Thr-CGT-3-1.lh    1.0293303               0.9906239
# tRNA-Thr-CGT-4-1.1t    0.9379909               1.0232333
# tRNA-Thr-CGT-4-1.2t    0.9816078               0.9987882
# tRNA-Thr-CGT-4-1.3t    1.0361118               1.0980929
# tRNA-Thr-CGT-4-1.lh    0.9945684               1.0318246
# tRNA-Thr-CGT-4-1.rh    1.0156730               1.0174199
# tRNA-Thr-TGT-2-1.lh    0.9947560               1.0140980
# tRNA-Thr-TGT-3-1.lh    0.9954089               1.0227725
# tRNA-Thr-TGT-5-1.1t    1.0879392               1.1121732
# tRNA-Thr-TGT-5-1.lh    0.9895933               1.0064661
# tRNA-Trp-CCA-2-1.3t    0.9931816               0.9838301
# tRNA-Trp-CCA-2-1.rh    1.0266755               0.9894061
# tRNA-Trp-CCA-4-1.3t    0.9549949               0.9851783
# tRNA-Trp-CCA-4-1.rh    1.0500876               0.9549639
# tRNA-Tyr-GTA-2-1.2t    1.0125558               0.9799827
# tRNA-Tyr-GTA-2-1.lh    0.9885329               1.0057687
# tRNA-Val-AAC-3-1.2t    0.9987711               0.9851809
# tRNA-Val-AAC-3-1.3t    0.7042712               0.9563165
# tRNA-Val-AAC-3-1.rh    0.9664629               1.0332160
# tRNA-Val-CAC-(6)1-1.3t 0.9737157               0.9151678
# tRNA-Val-CAC-(6)1-1.rh 0.9654586               1.0251867
# tRNA-Val-CAC-2-1.3t    1.1796376               1.1425862
# tRNA-Val-CAC-2-1.rh    0.9935905               1.0213672
# tRNA-Val-CAC-3-1.3t    1.1380931               1.0522334
# tRNA-Val-CAC-3-1.rh    1.0364274               0.9723612
# tRNA-Val-CAC-6-1.3t    1.1263933               0.9352014
# tRNA-Val-CAC-6-1.rh    1.0586836               0.9958632
# tRNA-Val-TAC-(2)1-1.2t 1.0828899               0.9786826
# TuD_NC                 1.0000000               1.0000000
#                        HALLMARK_WNT_BETA_CATENIN_SIGNALING
# tRF_Ala_AGC_2          1.0002039
# tRF_Ala_AGC.TGC_2      1.1009208
# tRF_Ala_CGC_2          1.0078764
# tRF_Ala_CGC.AGC.TGC_5  0.9963158
# tRF_Ala_TGC_2          0.9949599
# tRF_Ala_TGC.AGC_2      0.9632507
# tRF_Ala_TGC.AGC_6      1.0038408
# tRF_Arg_ACG_2          0.9957227
# tRF_Arg_CCG.CCT_3      1.0299174
# tRF_Arg_CCT_2          0.9806261
# tRF_Arg_CCT_3          1.0327488
# tRF_Arg_TCG_2          0.9835676
# tRF_Arg_TCG.CCG_2      0.9908378
# tRF_Arg_TCT_2          0.9862609
# tRF_Arg_TCT_4          0.9908195
# tRF_Asn_GTT_2          0.9961472
# tRF_Asp_GTC_2          1.0822954
# tRF_Cys.Ala_GCA.AGC_3  0.9790272
# tRF_Gln_CTG_2          1.0040067
# tRF_Gln_CTG.TTG_2      0.9985816
# tRF_Gln_TTG.CTG_2      0.9498016
# tRF_Glu_CTC_2          0.9961852
# tRF_Glu_TTC_2          1.0229983
# tRF_Glu_TTC_4          0.9998809
# tRF_Gly_CCC_2          0.9790744
# tRF_Gly_GCC_2          0.9908565
# tRF_Gly_GCC.CCC_4      1.0055067
# tRF_Gly_TCC_2          0.9767031
# tRF_Gly_TCC_4          0.9845799
# tRF_His_GTG_2          1.0226240
# ⋮                      ⋮
# tRNA-Thr-CGT-3-1.2t    1.0090553
# tRNA-Thr-CGT-3-1.lh    1.0441343
# tRNA-Thr-CGT-4-1.1t    0.9251931
# tRNA-Thr-CGT-4-1.2t    0.9875879
# tRNA-Thr-CGT-4-1.3t    1.1773317
# tRNA-Thr-CGT-4-1.lh    0.9403602
# tRNA-Thr-CGT-4-1.rh    0.9363867
# tRNA-Thr-TGT-2-1.lh    0.9903574
# tRNA-Thr-TGT-3-1.lh    0.9532755
# tRNA-Thr-TGT-5-1.1t    1.1702270
# tRNA-Thr-TGT-5-1.lh    1.0486130
# tRNA-Trp-CCA-2-1.3t    0.9466887
# tRNA-Trp-CCA-2-1.rh    1.0635306
# tRNA-Trp-CCA-4-1.3t    0.8123054
# tRNA-Trp-CCA-4-1.rh    1.0173998
# tRNA-Tyr-GTA-2-1.2t    1.0543363
# tRNA-Tyr-GTA-2-1.lh    0.9861634
# tRNA-Val-AAC-3-1.2t    0.9458603
# tRNA-Val-AAC-3-1.3t    0.5068576
# tRNA-Val-AAC-3-1.rh    0.9697953
# tRNA-Val-CAC-(6)1-1.3t 0.9843137
# tRNA-Val-CAC-(6)1-1.rh 1.0401518
# tRNA-Val-CAC-2-1.3t    1.0224445
# tRNA-Val-CAC-2-1.rh    0.9805599
# tRNA-Val-CAC-3-1.3t    0.8798096
# tRNA-Val-CAC-3-1.rh    1.0275989
# tRNA-Val-CAC-6-1.3t    0.9585025
# tRNA-Val-CAC-6-1.rh    0.9738182
# tRNA-Val-TAC-(2)1-1.2t 1.0925056
# TuD_NC                 1.0000000
#                        HALLMARK_XENOBIOTIC_METABOLISM
# tRF_Ala_AGC_2          1.0183916
# tRF_Ala_AGC.TGC_2      1.0111116
# tRF_Ala_CGC_2          1.0021877
# tRF_Ala_CGC.AGC.TGC_5  1.0054794
# tRF_Ala_TGC_2          0.9951328
# tRF_Ala_TGC.AGC_2      0.9666435
# tRF_Ala_TGC.AGC_6      1.0063815
# tRF_Arg_ACG_2          1.0009187
# tRF_Arg_CCG.CCT_3      1.0113139
# tRF_Arg_CCT_2          1.0019271
# tRF_Arg_CCT_3          0.9991752
# tRF_Arg_TCG_2          0.9914895
# tRF_Arg_TCG.CCG_2      1.0257694
# tRF_Arg_TCT_2          1.0006902
# tRF_Arg_TCT_4          0.9884492
# tRF_Asn_GTT_2          1.0092449
# tRF_Asp_GTC_2          0.9246440
# tRF_Cys.Ala_GCA.AGC_3  1.0080148
# tRF_Gln_CTG_2          1.0510153
# tRF_Gln_CTG.TTG_2      1.0060424
# tRF_Gln_TTG.CTG_2      1.1171209
# tRF_Glu_CTC_2          1.0191876
# tRF_Glu_TTC_2          1.0052324
# tRF_Glu_TTC_4          0.9980703
# tRF_Gly_CCC_2          0.9988671
# tRF_Gly_GCC_2          0.9981105
# tRF_Gly_GCC.CCC_4      0.9817489
# tRF_Gly_TCC_2          0.9989821
# tRF_Gly_TCC_4          1.0042405
# tRF_His_GTG_2          1.0016662
# ⋮                      ⋮
# tRNA-Thr-CGT-3-1.2t    0.9763662
# tRNA-Thr-CGT-3-1.lh    0.9399526
# tRNA-Thr-CGT-4-1.1t    1.0151197
# tRNA-Thr-CGT-4-1.2t    0.9854566
# tRNA-Thr-CGT-4-1.3t    1.0026976
# tRNA-Thr-CGT-4-1.lh    1.0499545
# tRNA-Thr-CGT-4-1.rh    1.0911474
# tRNA-Thr-TGT-2-1.lh    1.0136605
# tRNA-Thr-TGT-3-1.lh    0.9955070
# tRNA-Thr-TGT-5-1.1t    1.1594639
# tRNA-Thr-TGT-5-1.lh    1.0152828
# tRNA-Trp-CCA-2-1.3t    1.0898352
# tRNA-Trp-CCA-2-1.rh    0.9874608
# tRNA-Trp-CCA-4-1.3t    0.9778116
# tRNA-Trp-CCA-4-1.rh    0.9514808
# tRNA-Tyr-GTA-2-1.2t    0.9581125
# tRNA-Tyr-GTA-2-1.lh    1.0299965
# tRNA-Val-AAC-3-1.2t    0.9858794
# tRNA-Val-AAC-3-1.3t    0.8154443
# tRNA-Val-AAC-3-1.rh    0.9960267
# tRNA-Val-CAC-(6)1-1.3t 1.0274727
# tRNA-Val-CAC-(6)1-1.rh 1.0290659
# tRNA-Val-CAC-2-1.3t    0.8591124
# tRNA-Val-CAC-2-1.rh    1.0159101
# tRNA-Val-CAC-3-1.3t    0.7758204
# tRNA-Val-CAC-3-1.rh    0.9685089
# tRNA-Val-CAC-6-1.3t    0.8002493
# tRNA-Val-CAC-6-1.rh    0.9521745
# tRNA-Val-TAC-(2)1-1.2t 1.0100954
# TuD_NC                 1.0000000
